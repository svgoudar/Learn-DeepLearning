# %% [markdown]
# | Category        | Examples              | Key Application   |
# | --------------- | --------------------- | ----------------- |
# | Feedforward     | MLP                   | Tabular data      |
# | Convolutional   | CNN, ResNet           | Image, video      |
# | Recurrent       | LSTM, GRU             | Time series, text |
# | Attention-based | Bahdanau, Transformer | NLP, vision       |
# | Generative      | VAE, GAN              | Data synthesis    |
# | Metric Learning | Siamese, Triplet      | Similarity tasks  |
# | Graph-based     | GCN, GAT              | Graph data        |
# | Reinforcement   | DQN, PPO              | Decision systems  |
# | Hybrid          | CapsNet, ResNet       | Advanced vision   |
