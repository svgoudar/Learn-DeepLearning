# %% [markdown]
# ```{contents}
# ```
#
# ## Loss Function vs Cost Function
#
# Both measure the difference between **actual output (y)** and **predicted output (ŷ)**.
# The difference is **how many samples they operate on at a time.**
#
# ---
#
# ### Loss Function
#
# **Computed per data point**
#
# * Forward pass → get ŷ for **one sample**
# * Compute loss, e.g.
#   `Loss = (y − ŷ)²`  (MSE example)
# * Backpropagation happens **after every sample**
# * Weights update **for each data point**
#
# **Use case:** Stochastic / sample-wise training
#
# ---
#
# ###  Cost Function
#
# **Computed over all data points (or a batch)**
#
# * Forward pass on **all N samples**
# * Compute error for each: (yᵢ − ŷᵢ)²
# * Aggregate:
#   `Cost = (1/N) Σ (yᵢ − ŷᵢ)²`
# * Backpropagation happens **once**
# * Weights update **once** for the whole dataset (or batch)
#
# **Use case:** Batch / full training
#
# ---
#
# **In summary**
#
# | Aspect             | Loss Function       | Cost Function             |
# | ------------------ | ------------------- | ------------------------- |
# | Computation scope  | One sample          | All samples or batch      |
# | Formula example    | (y − ŷ)²            | (1/N) Σ (yᵢ − ŷᵢ)²        |
# | Forward + backward | Per sample          | Once per batch/full data  |
# | Weight update      | After every sample  | Once after aggregation    |
# | Common use         | Stochastic training | Batch/mini-batch training |
#
#
#
# ```{dropdown} Click here for Sections
# ```{tableofcontents}
